# %%
import pandas as pd

# %%
year = 2020
str = 'https://www.pro-football-reference.com/years/{}/rushing.htm'

# %%
url2 = str.format(year)

# %%
df = pd.read_html(url2, header = 1)

# %%
rb_df = df[0]
# Out:
# 384

# %%
df = rb_df.drop(rb_df[rb_df.Player == 'Player'].index) #delete the rows with 'Age' in column 'Age'
rb_df = df[['Player', 'Tm', 'Pos', 'Age', 'Att', 'Yds', 'TD', 'Fmb']]

# %%
rbdf = rb_df.loc[(rb_df['Pos'] == 'RB')] #locate rows that only contain 
rbdf
# Out:
#                    Player   Tm Pos Age  Att   Yds  TD Fmb
# 0        Derrick Henry *+  TEN  RB  26  378  2027  17   3
# 1            Dalvin Cook*  MIN  RB  25  312  1557  16   5
# 2            Josh Jacobs*  LVR  RB  22  273  1065  12   2
# 3        David Montgomery  CHI  RB  23  247  1070   8   1
# 4         Ezekiel Elliott  DAL  RB  25  244   979   6   6
# 5          James Robinson  JAX  RB  22  240  1070   7   3
# 6            Kenyan Drake  ARI  RB  26  239   955  10   3
# 7         Jonathan Taylor  IND  RB  21  232  1169  11   1
# 9            Aaron Jones*  GNB  RB  26  201  1104   9   2
# 11            Todd Gurley  ATL  RB  26  195   678   9   2
# 12        Ronald Jones II  TAM  RB  23  192   978   7   2
# 13            Nick Chubb*  CLE  RB  25  190  1067  12   1
# 14             Frank Gore  NYJ  RB  37  187   653   2   1
# 16  Clyde Edwards-Helaire  KAN  RB  21  181   803   4   0
# 18           James Conner  PIT  RB  25  169   721   6   2
# 19             Mike Davis  CAR  RB  27  165   642   6   1
# 20          Miles Sanders  PHI  RB  23  164   867   6   4
# 23       Devin Singletary  BUF  RB  23  156   687   2   1
# 25          David Johnson  HOU  RB  29  147   691   6   2
# 31           Chris Carson  SEA  RB  26  141   681   5   1
# 32      Darrell Henderson  LAR  RB  23  138   624   5   0
