# %%
import pandas as pd

# %%
year = 2021
str = 'https://www.pro-football-reference.com/years/{}/rushing.htm'

# %%
url2 = str.format(year)

# %%
df = pd.read_html(url2, header = 1)

# %%
df
# Out:
#       Rk               Player   Tm Age  Pos  G GS Att  Yds TD 1D Lng  Y/A  \
# 0      1            Joe Mixon  CIN  25   rb  1  1  29  127  1  6  19  4.4
# 1      2          Mark Ingram  HOU  32   rb  1  1  26   85  1  4  11  3.3
# 2      3        Damien Harris  NWE  24   rb  1  1  23  100  0  6  35  4.3
# 3      4  Christian McCaffrey  CAR  25   rb  1  1  21   98  0  2  18  4.7
# 4      5          Dalvin Cook  MIN  26   rb  1  1  20   61  1  5  17  3.1
# ..   ...                  ...  ...  ..  ... .. ..  ..  ... .. ..  ..  ...
# 129  126          Jonnu Smith  NWE  26   te  1  1   1    6  0  0   6  6.0
# 130  127  Rhamondre Stevenson  NWE  23  NaN  1  0   1    2  0  0   2  2.0
# 131  128        Freddie Swain  SEA  23  NaN  1  0   1    5  0  0   5  5.0
# 132  129      Darrel Williams  KAN  26  NaN  1  0   1    4  0  0   4  4.0
# 133  130         Robert Woods  LAR  29   wr  1  1   1    7  0  0   7  7.0
#
#        Y/G Fmb
# 0    127.0   0
# 1     85.0   0
# 2    100.0   1
# 3     98.0   0
# 4     61.0   1
# ..     ...  ..
# 129    6.0   1
# 130    2.0   1
# 131    5.0   0
# 132    4.0   0
# 133    7.0   0
#
# [130 rows x 15 columns]

# %%
rb_df = df[0]

# %%
df = rb_df.drop(rb_df[rb_df.Player == 'Player'].index) #delete the rows with 'Age' in column 'Age'
rb_df = df[['Player', 'Tm', 'Pos', 'Age', 'Att', 'Yds', 'TD', 'Fmb']]

# %%
rbdf = rb_df.loc[(rb_df['Pos'] == 'RB')] #locate rows that only contain

# %%
rbdf.to_csv(r'C:\Users\Steve.Lin\Desktop\test\Resources\rb_data.csv', index=False)
